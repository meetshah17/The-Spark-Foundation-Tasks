# %% [markdown]
# # GRIP @ The Sparks Foundation.
# ## Task 4:- Exploratory Data Analysis - Terrorism
# ## Problem Statement : As a security/defense analyst, try to find out the hot zone of terrorism.What all security issues and insights you can derive by EDA?
# # Author:- Meet Shah¶

# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Import Dataset

# %%
tsf= pd.read_csv("C:\\Users\\dell\\OneDrive\\Desktop\\globalterrorismdb_0718dist.csv", encoding = "ISO-8859-1", engine='python')
tsf
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
tsf.columns # it will give us  all columns names.
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
tsf.info # it will give us information about entire dataset.
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %%
tsf.isnull() #it will check whether null values are present or not.
# Out:
#         eventid  iyear  imonth   iday  approxdate  extended  resolution  \
# 0         False  False   False  False        True     False        True
# 1         False  False   False  False        True     False        True
# 2         False  False   False  False        True     False        True
# 3         False  False   False  False        True     False        True
# 4         False  False   False  False        True     False        True
# ...         ...    ...     ...    ...         ...       ...         ...
# 181686    False  False   False  False        True     False        True
# 181687    False  False   False  False        True     False        True
# 181688    False  False   False  False        True     False        True
# 181689    False  False   False  False        True     False        True
# 181690    False  False   False  False        True     False        True
#
#         country  country_txt  region  ...  addnotes  scite1  scite2  scite3  \
# ...

# %% [markdown]
# ## Taking whole dataset partialy and Cleaned it
# ### Taking around 10-15 columns individually analyse whole dataset and remove unnecessary columns.
# ### Here we use iloc function to get information partialy and if there is any null value or unnecessary columns are present then we'll drop it.

# %%
sd = tsf.iloc[:,:10]
sd
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region
# ...

# %%
final_ed = sd.drop(['approxdate','resolution','extended'],axis=1)
final_ed
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  region
# 0       197000000001   1970       7     2       58  Dominican Republic       2
# 1       197000000002   1970       0     0      130              Mexico       1
# 2       197001000001   1970       1     0      160         Philippines       5
# 3       197001000002   1970       1     0       78              Greece       8
# 4       197001000003   1970       1     0      101               Japan       4
# ...              ...    ...     ...   ...      ...                 ...     ...
# 181686  201712310022   2017      12    31      182             Somalia      11
# 181687  201712310029   2017      12    31      200               Syria      10
# 181688  201712310030   2017      12    31      160         Philippines       5
# 181689  201712310031   2017      12    31       92               India       6
# 181690  201712310032   2017      12    31      160         Philippines       5
#
# ...

# %%
fd = tsf.iloc[:,10:26]
fd
# Out:
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# 2                    Southeast Asia           Tarlac        Unknown
# 3                    Western Europe           Attica         Athens
# 4                         East Asia          Fukouka        Fukouka
# ...                             ...              ...            ...
# 181686           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow
# 181687   Middle East & North Africa         Lattakia         Jableh
# 181688               Southeast Asia      Maguindanao       Kubentog
# 181689                   South Asia          Manipur         Imphal
# 181690               Southeast Asia      Maguindanao  Cotabato City
#
#          latitude   longitude  specificity  vicinity  \
# 0       18.456792  -69.951164          1.0         0
# ...

# %%
final_jd = fd.drop(['multiple'],axis=1)
final_jd
# Out:
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# 2                    Southeast Asia           Tarlac        Unknown
# 3                    Western Europe           Attica         Athens
# 4                         East Asia          Fukouka        Fukouka
# ...                             ...              ...            ...
# 181686           Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow
# 181687   Middle East & North Africa         Lattakia         Jableh
# 181688               Southeast Asia      Maguindanao       Kubentog
# 181689                   South Asia          Manipur         Imphal
# 181690               Southeast Asia      Maguindanao  Cotabato City
#
#          latitude   longitude  specificity  vicinity  \
# 0       18.456792  -69.951164          1.0         0
# ...

# %%
gd = tsf.iloc[:,26:41]
gd
# Out:
#         success  suicide  attacktype1                 attacktype1_txt  \
# 0             1        0            1                   Assassination
# 1             1        0            6     Hostage Taking (Kidnapping)
# 2             1        0            1                   Assassination
# 3             1        0            3               Bombing/Explosion
# 4             1        0            7  Facility/Infrastructure Attack
# ...         ...      ...          ...                             ...
# 181686        1        0            2                   Armed Assault
# 181687        1        0            3               Bombing/Explosion
# 181688        1        0            7  Facility/Infrastructure Attack
# 181689        0        0            3               Bombing/Explosion
# 181690        0        0            3               Bombing/Explosion
#
#         attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# ...

# %%
final_hd = gd.drop(['suicide','attacktype2','attacktype2_txt','attacktype3','attacktype3_txt'],axis=1)
final_hd
# Out:
#         success  attacktype1                 attacktype1_txt  targtype1  \
# 0             1            1                   Assassination         14
# 1             1            6     Hostage Taking (Kidnapping)          7
# 2             1            1                   Assassination         10
# 3             1            3               Bombing/Explosion          7
# 4             1            7  Facility/Infrastructure Attack          7
# ...         ...          ...                             ...        ...
# 181686        1            2                   Armed Assault          4
# 181687        1            3               Bombing/Explosion          4
# 181688        1            7  Facility/Infrastructure Attack         14
# 181689        0            3               Bombing/Explosion          2
# 181690        0            3               Bombing/Explosion         20
#
#                       targtype1_txt  targsubtype1  \
# 0       Private Citizens & Property          68.0
# ...

# %%
ad = tsf.iloc[:,41:56]
ad
# Out:
#                natlty1_txt  targtype2 targtype2_txt  targsubtype2  \
# 0       Dominican Republic        NaN           NaN           NaN
# 1                  Belgium        NaN           NaN           NaN
# 2            United States        NaN           NaN           NaN
# 3            United States        NaN           NaN           NaN
# 4            United States        NaN           NaN           NaN
# ...                    ...        ...           ...           ...
# 181686             Somalia        NaN           NaN           NaN
# 181687              Russia        NaN           NaN           NaN
# 181688         Philippines        NaN           NaN           NaN
# 181689               India        NaN           NaN           NaN
# 181690         Philippines        NaN           NaN           NaN
#
#        targsubtype2_txt corp2 target2  natlty2 natlty2_txt  targtype3  \
# 0                   NaN   NaN     NaN      NaN         NaN        NaN
# ...

# %%
final_td = ad.drop(tsf.iloc[:,42:56],axis = 'columns')
final_td
# Out:
#                natlty1_txt
# 0       Dominican Republic
# 1                  Belgium
# 2            United States
# 3            United States
# 4            United States
# ...                    ...
# 181686             Somalia
# 181687              Russia
# 181688         Philippines
# 181689               India
# 181690         Philippines
#
# [181691 rows x 1 columns]

# %%
ud = tsf.iloc[:,56:71]
ud
# Out:
#         natlty3 natlty3_txt                                       gname  \
# 0           NaN         NaN                                      MANO-D
# 1           NaN         NaN          23rd of September Communist League
# 2           NaN         NaN                                     Unknown
# 3           NaN         NaN                                     Unknown
# 4           NaN         NaN                                     Unknown
# ...         ...         ...                                         ...
# 181686      NaN         NaN                                  Al-Shabaab
# 181687      NaN         NaN                           Muslim extremists
# 181688      NaN         NaN  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689      NaN         NaN                                     Unknown
# 181690      NaN         NaN                                     Unknown
#
#        gsubname gname2 gsubname2 gname3 gsubname3 motive  guncertain1  \
# ...

# %%
bg = ud.drop(['natlty3','natlty3_txt'],axis=1)
bg
# Out:
#                                              gname gsubname gname2 gsubname2  \
# 0                                           MANO-D      NaN    NaN       NaN
# 1               23rd of September Communist League      NaN    NaN       NaN
# 2                                          Unknown      NaN    NaN       NaN
# 3                                          Unknown      NaN    NaN       NaN
# 4                                          Unknown      NaN    NaN       NaN
# ...                                            ...      ...    ...       ...
# 181686                                  Al-Shabaab      NaN    NaN       NaN
# 181687                           Muslim extremists      NaN    NaN       NaN
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)      NaN    NaN       NaN
# 181689                                     Unknown      NaN    NaN       NaN
# 181690                                     Unknown      NaN    NaN       NaN
#
# ...

# %%
tg = bg.drop(tsf.iloc[:,59:69],axis=1)
tg
# Out:
#                                              gname  nperps  nperpcap
# 0                                           MANO-D     NaN       NaN
# 1               23rd of September Communist League     7.0       NaN
# 2                                          Unknown     NaN       NaN
# 3                                          Unknown     NaN       NaN
# 4                                          Unknown     NaN       NaN
# ...                                            ...     ...       ...
# 181686                                  Al-Shabaab   -99.0       0.0
# 181687                           Muslim extremists   -99.0       0.0
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)   -99.0       0.0
# 181689                                     Unknown   -99.0       0.0
# 181690                                     Unknown   -99.0       0.0
#
# [181691 rows x 3 columns]

# %%
final_tf = tg.drop(['nperpcap'],axis=1)
final_tf
# Out:
#                                              gname  nperps
# 0                                           MANO-D     NaN
# 1               23rd of September Communist League     7.0
# 2                                          Unknown     NaN
# 3                                          Unknown     NaN
# 4                                          Unknown     NaN
# ...                                            ...     ...
# 181686                                  Al-Shabaab   -99.0
# 181687                           Muslim extremists   -99.0
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)   -99.0
# 181689                                     Unknown   -99.0
# 181690                                     Unknown   -99.0
#
# [181691 rows x 2 columns]

# %%
md = tsf.iloc[:,71:86]
md
# Out:
#         claimed  claimmode claimmode_txt  claim2  claimmode2 claimmode2_txt  \
# 0           NaN        NaN           NaN     NaN         NaN            NaN
# 1           NaN        NaN           NaN     NaN         NaN            NaN
# 2           NaN        NaN           NaN     NaN         NaN            NaN
# 3           NaN        NaN           NaN     NaN         NaN            NaN
# 4           NaN        NaN           NaN     NaN         NaN            NaN
# ...         ...        ...           ...     ...         ...            ...
# 181686      1.0       10.0       Unknown     NaN         NaN            NaN
# 181687      0.0        NaN           NaN     NaN         NaN            NaN
# 181688      0.0        NaN           NaN     NaN         NaN            NaN
# 181689      0.0        NaN           NaN     NaN         NaN            NaN
# 181690      0.0        NaN           NaN     NaN         NaN            NaN
#
# ...

# %%
td = md.drop(tsf.iloc[:,73:81],axis=1)
td
# Out:
#         claimed  claimmode  weaptype1 weaptype1_txt  weapsubtype1  \
# 0           NaN        NaN         13       Unknown           NaN
# 1           NaN        NaN         13       Unknown           NaN
# 2           NaN        NaN         13       Unknown           NaN
# 3           NaN        NaN          6    Explosives          16.0
# 4           NaN        NaN          8    Incendiary           NaN
# ...         ...        ...        ...           ...           ...
# 181686      1.0       10.0          5      Firearms           5.0
# 181687      0.0        NaN          6    Explosives          11.0
# 181688      0.0        NaN          8    Incendiary          18.0
# 181689      0.0        NaN          6    Explosives           7.0
# 181690      0.0        NaN          6    Explosives          16.0
#
#                                  weapsubtype1_txt  weaptype2
# 0                                             NaN        NaN
# ...

# %%
final_rd = td.drop(['weaptype2'],axis=1)
final_rd
# Out:
#         claimed  claimmode  weaptype1 weaptype1_txt  weapsubtype1  \
# 0           NaN        NaN         13       Unknown           NaN
# 1           NaN        NaN         13       Unknown           NaN
# 2           NaN        NaN         13       Unknown           NaN
# 3           NaN        NaN          6    Explosives          16.0
# 4           NaN        NaN          8    Incendiary           NaN
# ...         ...        ...        ...           ...           ...
# 181686      1.0       10.0          5      Firearms           5.0
# 181687      0.0        NaN          6    Explosives          11.0
# 181688      0.0        NaN          8    Incendiary          18.0
# 181689      0.0        NaN          6    Explosives           7.0
# 181690      0.0        NaN          6    Explosives          16.0
#
#                                  weapsubtype1_txt
# 0                                             NaN
# 1                                             NaN
# ...

# %%
re = tsf.iloc[:,86:101]
re
# Out:
#        weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0                NaN           NaN              NaN        NaN           NaN
# 1                NaN           NaN              NaN        NaN           NaN
# 2                NaN           NaN              NaN        NaN           NaN
# 3                NaN           NaN              NaN        NaN           NaN
# 4                NaN           NaN              NaN        NaN           NaN
# ...              ...           ...              ...        ...           ...
# 181686           NaN           NaN              NaN        NaN           NaN
# 181687           NaN           NaN              NaN        NaN           NaN
# 181688           NaN           NaN              NaN        NaN           NaN
# 181689           NaN           NaN              NaN        NaN           NaN
# 181690           NaN           NaN              NaN        NaN           NaN
#
# ...

# %%
ew = re.drop(tsf.iloc[:,86:97],axis=1)
ew
# Out:
#                                                weapdetail  nkill  nkillus  \
# 0                                                     NaN    1.0      NaN
# 1                                                     NaN    0.0      NaN
# 2                                                     NaN    1.0      NaN
# 3                                               Explosive    NaN      NaN
# 4                                              Incendiary    NaN      NaN
# ...                                                   ...    ...      ...
# 181686                                                NaN    1.0      0.0
# 181687                   Mortars were used in the attack.    2.0      0.0
# 181688                                                NaN    0.0      0.0
# 181689           A thrown grenade was used in the attack.    0.0      0.0
# 181690  An explosive device containing a detonating co...    0.0      0.0
#
#         nkillter
# 0            NaN
# 1            NaN
# 2            NaN
# ...

# %%
final_me = ew.drop(['nkillus','nkillter'],axis=1)
final_me
# Out:
#                                                weapdetail  nkill
# 0                                                     NaN    1.0
# 1                                                     NaN    0.0
# 2                                                     NaN    1.0
# 3                                               Explosive    NaN
# 4                                              Incendiary    NaN
# ...                                                   ...    ...
# 181686                                                NaN    1.0
# 181687                   Mortars were used in the attack.    2.0
# 181688                                                NaN    0.0
# 181689           A thrown grenade was used in the attack.    0.0
# 181690  An explosive device containing a detonating co...    0.0
#
# [181691 rows x 2 columns]

# %%
ye = tsf.iloc[:,101:116]
ye
# Out:
#         nwound  nwoundus  nwoundte  property  propextent propextent_txt  \
# 0          0.0       NaN       NaN         0         NaN            NaN
# 1          0.0       NaN       NaN         0         NaN            NaN
# 2          0.0       NaN       NaN         0         NaN            NaN
# 3          NaN       NaN       NaN         1         NaN            NaN
# 4          NaN       NaN       NaN         1         NaN            NaN
# ...        ...       ...       ...       ...         ...            ...
# 181686     2.0       0.0       0.0        -9         NaN            NaN
# 181687     7.0       0.0       0.0         1         4.0        Unknown
# 181688     0.0       0.0       0.0         1         4.0        Unknown
# 181689     0.0       0.0       0.0        -9         NaN            NaN
# 181690     0.0       0.0       0.0         0         NaN            NaN
#
#         propvalue                                        propcomment  \
# ...

# %%
final_op = ye.drop(['nwoundte','nwoundus','propextent_txt','nhours','ndays','nhostkid','nhostkidus','divert','ishostkid'],axis=1)
final_op
# Out:
#         nwound  property  propextent  propvalue  \
# 0          0.0         0         NaN        NaN
# 1          0.0         0         NaN        NaN
# 2          0.0         0         NaN        NaN
# 3          NaN         1         NaN        NaN
# 4          NaN         1         NaN        NaN
# ...        ...       ...         ...        ...
# 181686     2.0        -9         NaN        NaN
# 181687     7.0         1         4.0      -99.0
# 181688     0.0         1         4.0      -99.0
# 181689     0.0        -9         NaN        NaN
# 181690     0.0         0         NaN        NaN
#
#                                               propcomment kidhijcountry
# 0                                                     NaN           NaN
# 1                                                     NaN        Mexico
# 2                                                     NaN           NaN
# 3                                                     NaN           NaN
# ...

# %%
pe = tsf.iloc[:,116:]
pe
# Out:
#         ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0          0.0        NaN          NaN         NaN           NaN        NaN
# 1          1.0   800000.0          NaN         NaN           NaN        NaN
# 2          0.0        NaN          NaN         NaN           NaN        NaN
# 3          0.0        NaN          NaN         NaN           NaN        NaN
# 4          0.0        NaN          NaN         NaN           NaN        NaN
# ...        ...        ...          ...         ...           ...        ...
# 181686     NaN        NaN          NaN         NaN           NaN        NaN
# 181687     NaN        NaN          NaN         NaN           NaN        NaN
# 181688     NaN        NaN          NaN         NaN           NaN        NaN
# 181689     NaN        NaN          NaN         NaN           NaN        NaN
# 181690     NaN        NaN          NaN         NaN           NaN        NaN
#
# ...

# %%
rq = pe.drop(tsf.iloc[:,118:126],axis=1)
rq
# Out:
#         ransom  ransomamt                                             scite1  \
# 0          0.0        NaN                                                NaN
# 1          1.0   800000.0                                                NaN
# 2          0.0        NaN                                                NaN
# 3          0.0        NaN                                                NaN
# 4          0.0        NaN                                                NaN
# ...        ...        ...                                                ...
# 181686     NaN        NaN  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687     NaN        NaN  "Putin's 'victory' in Syria has turned into a ...
# 181688     NaN        NaN  "Maguindanao clashes trap tribe members," Phil...
# 181689     NaN        NaN  "Trader escapes grenade attack in Imphal," Bus...
# 181690     NaN        NaN  "Security tightened in Cotabato following IED ...
#
# ...

# %%
final_qw = rq.drop(['related'],axis=1)
final_qw
# Out:
#         ransom  ransomamt                                             scite1  \
# 0          0.0        NaN                                                NaN
# 1          1.0   800000.0                                                NaN
# 2          0.0        NaN                                                NaN
# 3          0.0        NaN                                                NaN
# 4          0.0        NaN                                                NaN
# ...        ...        ...                                                ...
# 181686     NaN        NaN  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687     NaN        NaN  "Putin's 'victory' in Syria has turned into a ...
# 181688     NaN        NaN  "Maguindanao clashes trap tribe members," Phil...
# 181689     NaN        NaN  "Trader escapes grenade attack in Imphal," Bus...
# 181690     NaN        NaN  "Security tightened in Cotabato following IED ...
#
# ...

# %% [markdown]
# ## Clean Dataset
# ### Concatenate whole clean dataset together and merge it in a one variable.

# %%
final_con = pd.concat([final_ed,final_jd,final_hd,final_td,final_tf,final_rd,final_me,final_op,final_qw],axis=1)
final_con # clean dataset.
# Out:
#              eventid  iyear  imonth  iday  country         country_txt  \
# 0       197000000001   1970       7     2       58  Dominican Republic
# 1       197000000002   1970       0     0      130              Mexico
# 2       197001000001   1970       1     0      160         Philippines
# 3       197001000002   1970       1     0       78              Greece
# 4       197001000003   1970       1     0      101               Japan
# ...              ...    ...     ...   ...      ...                 ...
# 181686  201712310022   2017      12    31      182             Somalia
# 181687  201712310029   2017      12    31      200               Syria
# 181688  201712310030   2017      12    31      160         Philippines
# 181689  201712310031   2017      12    31       92               India
# 181690  201712310032   2017      12    31      160         Philippines
#
#         region                   region_txt        provstate           city  \
# ...

# %%
final_con.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country', 'country_txt',
#        'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude',
#        'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2',
#        'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'success',
#        'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt',
#        'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1',
#        'natlty1_txt', 'gname', 'nperps', 'claimed', 'claimmode', 'weaptype1',
#        'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt', 'weapdetail',
#        'nkill', 'nwound', 'property', 'propextent', 'propvalue', 'propcomment',
#        'kidhijcountry', 'ransom', 'ransomamt', 'scite1', 'scite2', 'scite3',
#        'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %% [markdown]
# # Data Visualization and Analysis

# %%
# terrorist attack by region from 1970 to 2015
plt.figure(figsize=(20,10))
final_con.groupby(by='iyear')['region'].sum().sort_values(ascending=True).plot(kind='bar')
plt.show()

# %% [markdown]
# ### we can see that in 2014 highest attack occurs.

# %%
plt.figure(figsize=(20,10))
final_con.groupby(by='gname')['success'].sum().sort_values(ascending=True).plot(kind='line')

# %% [markdown]
# ### hezbollah gang success ratio is maximum then anyother gang.

# %%
plt.figure(figsize=(20,10))
final_con.groupby(by='country_txt')['region'].sum().sort_values(ascending=True).plot(kind='bar')

# %%
m = final_con.groupby(by='country_txt')['region'].sum().sort_values(ascending=True)
m.max
# Out:
# <bound method Series.max of country_txt
# St. Lucia                   2
# Antigua and Barbuda         2
# Falkland Islands            3
# North Korea                 4
# St. Kitts and Nevis         4
#                         ...
# Somalia                 45562
# India                   71760
# Afghanistan             76386
# Pakistan                86208
# Iraq                   246360
# Name: region, Length: 205, dtype: int64>

# %% [markdown]
# ### here we can see that Iraq has a maximum attacks.
# ## Take whole dataset of Iraq and analyse it.

# %%
iraq = final_con.loc[(final_con['country_txt'] =='Iraq')]
iraq
# Out:
#              eventid  iyear  imonth  iday  country country_txt  region  \
# 2854    197503010002   1975       3     1       95        Iraq      10
# 4385    197612150001   1976      12    15       95        Iraq      10
# 4393    197612180001   1976      12    18       95        Iraq      10
# 4402    197612240001   1976      12    24       95        Iraq      10
# 8688    197906150001   1979       6    15       95        Iraq      10
# ...              ...    ...     ...   ...      ...         ...     ...
# 181669  201712310002   2017      12    30       95        Iraq      10
# 181670  201712310003   2017      12    31       95        Iraq      10
# 181671  201712310004   2017      12    31       95        Iraq      10
# 181674  201712310007   2017      12    31       95        Iraq      10
# 181679  201712310012   2017      12    31       95        Iraq      10
#
#                         region_txt provstate          city  ...  ransom  \
# ...

# %%
plt.figure(figsize=(20,10))
final_con.groupby(by='region_txt')['region'].sum().sort_values(ascending=True).plot(kind='bar',color='#f10146')

# %% [markdown]
# ### Middle East & North Africa is the highest region where attacks occur.

# %%
plt.figure(figsize=(20,10))
city=iraq['city'].value_counts(ascending=True)
city.plot(kind='bar')
plt.show()
# Out:
# D:\Users\dell\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\dell\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
city.max
# Out:
# <bound method Series.max of Jahouni            1
# Tib district       1
# Ash Shariah        1
# Hawz               1
# Al-Azayziyah       1
#                 ...
# Fallujah         579
# Baqubah          745
# Kirkuk           925
# Mosul           2265
# Baghdad         7585
# Name: city, Length: 1513, dtype: int64>

# %% [markdown]
# ### baghdad is the hotest zone for terrorism
# ## Take whole dataset of baghdad and analyse it.

# %%
bagh = iraq.loc[(iraq['city'] =='Baghdad')]
bagh
# Out:
#              eventid  iyear  imonth  iday  country country_txt  region  \
# 4385    197612150001   1976      12    15       95        Iraq      10
# 4402    197612240001   1976      12    24       95        Iraq      10
# 10109   198001280004   1980       1    28       95        Iraq      10
# 10588   198004010019   1980       4     1       95        Iraq      10
# 11252   198006190004   1980       6    19       95        Iraq      10
# ...              ...    ...     ...   ...      ...         ...     ...
# 181463  201712220004   2017      12    22       95        Iraq      10
# 181499  201712240004   2017      12    24       95        Iraq      10
# 181564  201712270005   2017      12    27       95        Iraq      10
# 181626  201712290004   2017      12    29       95        Iraq      10
# 181646  201712300003   2017      12    30       95        Iraq      10
#
#                         region_txt provstate     city  ...  ransom  ransomamt  \
# ...

# %%
bagh.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country', 'country_txt',
#        'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude',
#        'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2',
#        'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'success',
#        'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt',
#        'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1',
#        'natlty1_txt', 'gname', 'nperps', 'claimed', 'claimmode', 'weaptype1',
#        'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt', 'weapdetail',
#        'nkill', 'nwound', 'property', 'propextent', 'propvalue', 'propcomment',
#        'kidhijcountry', 'ransom', 'ransomamt', 'scite1', 'scite2', 'scite3',
#        'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
att_types = bagh['attacktype1_txt'].value_counts(ascending=True).plot(kind='bar')
plt.show()

# %% [markdown]
# ### Bombing/explotion is the highest attack type in baghdad

# %%
plt.figure(figsize=(20,10))
tarty_types = bagh['targtype1_txt'].value_counts(ascending=True).plot(kind='bar',color='#000080')
plt.show()

# %% [markdown]
# ### Private Citizens and properties is the highest target type in baghdad.

# %%
plt.figure(figsize=(20,10))
tarty_types = bagh['targsubtype1_txt'].value_counts(ascending=True).plot(kind='bar',color='#000080')
plt.show()

# %% [markdown]
# ### Unnamed civilization/Unsapecified is the most targeted subtype of Terrorist.

# %% [markdown]
# # Summary:

# %% [markdown]
# ### - we can see that in 2014 highest attack occurs.
# ### - Iraq has a maximum attacks.
# ### - Middle East & North Africa is the highest region where attacks occur.¶
# ### - baghdad is the hotest zone for terrorism.
# ### - Bombing/explotion is the highest attack type in baghdad.
# ### - Private Citizens and properties is the highest target type in baghdad.
# ### -  Unnamed civilization/Unsapecified is the most targeted subtype of Terrorist.
